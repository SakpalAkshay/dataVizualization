# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/csuftitan/Downloads/Pandas/amazon_reviews.csv')

# %% [markdown]
# ## Shape Attribute

# %% [markdown]
# This gives out information regarding dimension of the data that you are using

# %%
df.shape # It has 1000 rows and 10 columns
# Out:
# (1000, 10)

# %% [markdown]
# ## Column attribute

# %% [markdown]
# Provide column names of our data frames

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# ## Dtypes

# %% [markdown]
# Provides information about all data types present in the dataframe that you are using

# %%
df.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                     float64
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %% [markdown]
# ## Values

# %% [markdown]
# is a attribute with respect to series, get of all associated values for a column in an array or list format

# %%
df['UserId'].values
# Out:
# array(['AR89H8T4PVWSL', 'A15VHPHU0V8GOH', 'A3CG7K9OQ5M0RI',
#        'A1C1Y0S6QPBM4W', 'A2MERSI1KHYIQB', 'AR89H8T4PVWSL',
#        'A3B1XBG7CMYK41', 'A15GK1KULYHI12', 'A1KPALLWZ73M27',
#        'A3ET5C2A3CCNWJ', 'A1PMAOD2KBB10Z', 'A371Z04GWURCYC',
#        'AQ88AZTV8PYC0', 'A36FEPUTDN12KA', 'A30ZAP242J449S',
#        'A1FCMQT7KJXCIQ', 'A13EBBWOMC0FUI', 'A1DMR4TXV10JBB',
#        'A254HJEKU1NF2Y', 'A2OWR2PL3DLWS4', 'AT40UJ4IXZRCF',
#        'A2ZJDGVJ45AR5W', 'AINMG64N0CBEG', 'A13YNYAYG5JZVU',
#        'A3PECZX773ME74', 'A3NVD74QJYFCWS', 'AYVA1OS3PL19K',
#        'A1HFPTFCKUSFEI', 'A1ESB4HAI5G97C', 'A3C7KI4396ZZEV',
#        'A2EUS5A4V7AKAD', 'APL8B8Y7T0ED8', 'A1B4T1Z4TJZUSX',
#        'A1B4PMJVY3Q38W', 'A3KTRR4QTE2LUJ', 'A35D075O30ZJS3',
#        'A1SQPBEUL9VEDR', 'A2AE869K5GLGN5', 'A3AO8XB02QGYAX',
#        'A3H8288VHL1607', 'A2MLVRK0WCRA9W', 'A3833VXG1CNT1Q',
#        'AIZVI0OK7XSIZ', 'A1N4NAIHZF4J7X', 'AC64J76R8B1M9',
#        'A3W23D5PTALR0L', 'A2GGQ93VXT606F', 'A18KK6UY5352LQ',
# ...
